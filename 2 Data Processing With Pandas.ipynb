# %% [markdown]
# # The Series data structure

# %% [markdown]
# ## pd.Series()

# %%
import pandas as pd

# %% [markdown]
# ### pd.series?
#
# ### documentation about Series

# %%
pd.Series?

# %% [markdown]
# ### Create the list and pass it to the pd.Series()

# %%
animals = ['Tiger', 'Bear', 'Mouse']

pd.Series(animals)
# Out:
# 0    Tiger
# 1     Bear
# 2    Mouse
# dtype: object

# %%
numbers = [1,2,3]
pd.Series(numbers)
# Out:
# 0    1
# 1    2
# 2    3
# dtype: int64

# %%
animals = ['Tiger','Bear',None]
pd.Series(animals)
# Out:
# 0    Tiger
# 1     Bear
# 2     None
# dtype: object

# %%
numbers = [1,2,None]
pd.Series(numbers)
# Out:
# 0    1.0
# 1    2.0
# 2    NaN
# dtype: float64

# %%
mix = ['Tiger',1, 1.2, None]
pd.Series(mix)
# Out:
# 0    Tiger
# 1        1
# 2      1.2
# 3     None
# dtype: object

# %% [markdown]
# ### check equality of np.nanand None

# %%
import numpy as np
np.nan == None
# Out:
# False

# %%
np.nan == np.nan
# Out:
# False

# %% [markdown]
# ### np.isnan()
# #### right way to check equality

# %%
np.isnan(np.nan)
# Out:
# True

# %% [markdown]
# ### pass dictionary to Series()

# %%
dic = {'India':'hindi', 'US':'English', 'Chin':'China'}
s = pd.Series(dic)
s
# Out:
# Chin       China
# India      hindi
# US       English
# dtype: object

# %% [markdown]
# ### s.index
# to get index from series

# %%
s.index
# Out:
# Index(['Chin', 'India', 'US'], dtype='object')

# %% [markdown]
# #### also we can pass 1st list as data and 2nd list as index[ ]
# ### pd.Series([ ], index=[ ])

# %%
pd.Series(['hindi','English','China'], index=['India','America','Chin'])
# Out:
# India        hindi
# America    English
# Chin         China
# dtype: object

# %%
sports = {'Archery': 'Bhutan',
          'Golf': 'Scotland',
          'Sumo': 'Japan',
          'Taekwondo': 'South Korea'}

s = pd.Series(sports, index=['Golf', 'Sumo','Hockye'])
s
# Out:
# Golf      Scotland
# Sumo         Japan
# Hockye         NaN
# dtype: object

# %% [markdown]
# # 2. Querying a Series

# %%
sports = {'Archery': 'Bhutan',
          'Golf': 'Scotland',
          'Sumo': 'Japan',
          'Taekwondo': 'South Korea'}
s = pd. Series(sports)
s
# Out:
# Archery           Bhutan
# Golf            Scotland
# Sumo               Japan
# Taekwondo    South Korea
# dtype: object

# %% [markdown]
# ### s.iloc[index_num]
#
# #### return data at index_number
#
# index number start from 0 to lengh-1

# %%
s.iloc[3]
# Out:
# 'South Korea'

# %% [markdown]
# ## s.loc[index_name]
#
# ### return data at index_name

# %%
s.loc['Golf']
# Out:
# 'Scotland'

# %%
s[3]
# Out:
# 'South Korea'

# %%
s['Golf']
# Out:
# 'Scotland'

# %% [markdown]
# ## Key error

# %%
sports = {99: 'Bhutan',
          100: 'Scotland',
          101: 'Japan',
          102: 'South Korea'}
s = pd.Series(sports)
s
# Out:
# 99          Bhutan
# 100       Scotland
# 101          Japan
# 102    South Korea
# dtype: object

# %%
s[0]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-50-4e98c4f87897> in <module>()
# ----> 1 s[0]
#
# ~\Anaconda3\lib\site-packages\pandas\core\series.py in __getitem__(self, key)
#     599         key = com._apply_if_callable(key, self)
#     600         try:
# --> 601             result = self.index.get_value(self, key)
#     602
#     603             if not is_scalar(result):
#
# ~\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_value(self, series, key)
#    2475         try:
#    2476             return self._engine.get_value(s, k,
# -> 2477                                           tz=getattr(series.dtype, 'tz', None))
#    2478         except KeyError as e1:
#    2479             if len(self) > 0 and self.inferred_type in ['integer', 'boolean']:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_value()
#
# ...

# %%
s = pd.Series([100.00,101.00,102.00])
s
# Out:
# 0    100.0
# 1    101.0
# 2    102.0
# dtype: float64

# %% [markdown]
# ### using loop get total of above data

# %%
total = 0
for item in s:
    total = total + item
print(total)
# Out:
# 303.0

# %% [markdown]
# ## np.sum()
# ### most efficient methode use insted of loop
# get sum of all items in one line

# %%
import numpy as np
np.sum(s)
# Out:
# 303.0

# %% [markdown]
# ### create a big series of random numbers

# %%
s = pd.Series(np.random.randint(0,1000,100000))
s.head() #1st 5 element
# Out:
# 0    689
# 1    394
# 2    238
# 3    157
# 4    463
# dtype: int32

# %%
len(s)
# Out:
# 100000

# %% [markdown]
# ## timeit
# ### Time execution of a Python statement or expression

# %%
# %%timeit -n 100
summary = 0
for item in s:
    summary+=item
# Out:
# 11.7 ms ± 220 µs per loop (mean ± std. dev. of 7 runs, 100 loops each)

# %%
# %%timeit -n 100
t = np.sum(s)
# Out:
# 638 µs ± 156 µs per loop (mean ± std. dev. of 7 runs, 100 loops each)

# %% [markdown]
# ### adds two to each item in s using broadcasting

# %%
print(s.head())
s += 2
s.head()
# Out:
# 0    695
# 1    400
# 2    244
# 3    163
# 4    469
# dtype: int32
# 0    697
# 1    402
# 2    246
# 3    165
# 4    471
# dtype: int32

# %% [markdown]
# ### above operation using loop

# %%
for index, element in s.iteritems():
    s.set_value(index, element + 2)
s.head()
# Out:
# 0    703
# 1    408
# 2    252
# 3    171
# 4    477
# dtype: int32

# %%
# %%timeit -n 10
s = pd.Series(np.random.randint(0,1000,10000))
for label, value in s.iteritems():
    s.loc[label]= value+2
# Out:
# 770 ms ± 32.2 ms per loop (mean ± std. dev. of 7 runs, 10 loops each)

# %%
# %%timeit -n 10
s = pd.Series(np.random.randint(0,1000,10000))
s+=2
# Out:
# 405 µs ± 138 µs per loop (mean ± std. dev. of 7 runs, 10 loops each)

# %% [markdown]
# ### to add new data in series

# %%
s = pd.Series([1,2,3])
s.loc['India'] = 'Sahil'
s
# Out:
# 0            1
# 1            2
# 2            3
# India    Sahil
# dtype: object

# %% [markdown]
# ## .append()
#
# ### append series to anather series

# %%
original_sports = pd.Series({'Archery': 'Bhutan',
                             'Golf': 'Scotland',
                             'Sumo': 'Japan',
                             'Taekwondo': 'South Korea'})
cricket_loving_countries = pd.Series(['Australia',
                                      'Barbados',
                                      'Pakistan',
                                      'England'], 
                                   index=['Cricket',
                                          'Cricket',
                                          'Cricket',
                                          'Cricket'])
all_countries = original_sports.append(cricket_loving_countries)

# %%
original_sports
# Out:
# Archery           Bhutan
# Golf            Scotland
# Sumo               Japan
# Taekwondo    South Korea
# dtype: object

# %%
cricket_loving_countries
# Out:
# Cricket    Australia
# Cricket     Barbados
# Cricket     Pakistan
# Cricket      England
# dtype: object

# %%
all_countries
# Out:
# Archery           Bhutan
# Golf            Scotland
# Sumo               Japan
# Taekwondo    South Korea
# Cricket        Australia
# Cricket         Barbados
# Cricket         Pakistan
# Cricket          England
# dtype: object

# %%
all_countries.loc['Cricket']
# Out:
# Cricket    Australia
# Cricket     Barbados
# Cricket     Pakistan
# Cricket      England
# dtype: object

# %% [markdown]
# # 4. The DataFrame Data Structure

# %%
import pandas as pd

purchase_1 = pd.Series({'Name':'Chris', 
                        'Item Purchased':'Dog Food', 
                        'Cost':22.50})

purchase_2 = pd.Series({'Name': 'Kevyn',
                        'Item Purchased': 'Kitty Litter',
                        'Cost': 2.50})

purchase_3 = pd.Series({'Name': 'Vinod',
                        'Item Purchased': 'Bird Seed',
                        'Cost': 5.00})

# DataFrame is collection of Series
df = pd.DataFrame([purchase_1, purchase_2, purchase_3], index=['store1', 'store1', 'store2'])
df
# Out:
#         Cost Item Purchased   Name
# store1  22.5       Dog Food  Chris
# store1   2.5   Kitty Litter  Kevyn
# store2   5.0      Bird Seed  Vinod

# %% [markdown]
# ### get store2 from dataframe

# %%
df.loc['store2']
# Out:
# Cost                      5
# Item Purchased    Bird Seed
# Name                  Vinod
# Name: store2, dtype: object

# %%
type(df.loc['store2'])
# Out:
# pandas.core.series.Series

# %%
df.loc['store1']
# Out:
#         Cost Item Purchased   Name
# store1  22.5       Dog Food  Chris
# store1   2.5   Kitty Litter  Kevyn

# %% [markdown]
# ### Get store2 row and get cost from that row

# %%
df.loc['store2','Cost']
# Out:
# 5.0

# %% [markdown]
# ### get transpose of dataframe

# %%
df.T
# Out:
#                   store1        store1     store2
# Cost                22.5           2.5          5
# Item Purchased  Dog Food  Kitty Litter  Bird Seed
# Name               Chris         Kevyn      Vinod

# %%
df.T.loc['Cost']
# Out:
# store1    22.5
# store1     2.5
# store2       5
# Name: Cost, dtype: object

# %%
df['Cost']
# Out:
# store1    22.5
# store1     2.5
# store2     5.0
# Name: Cost, dtype: float64

# %%
df.loc['store1']['Cost']
# Out:
# store1    22.5
# store1     2.5
# Name: Cost, dtype: float64

# %% [markdown]
# ### get name and cost from all rows

# %%
df.loc[:, ['Name', 'Cost']]
# Out:
#          Name  Cost
# store1  Chris  22.5
# store1  Kevyn   2.5
# store2  Vinod   5.0

# %% [markdown]
# ## df.drop()
#
# to delet the record

# %% [markdown]
# df.drop('store1')

# %%
df.drop('store1')
# Out:
#         Cost Item Purchased   Name
# store2   5.0      Bird Seed  Vinod

# %% [markdown]
# ### df is unchanged

# %%
df
# Out:
#         Cost Item Purchased   Name
# store1  22.5       Dog Food  Chris
# store1   2.5   Kitty Litter  Kevyn
# store2   5.0      Bird Seed  Vinod

# %% [markdown]
# the right way if you want original remains unchanged

# %%
copy_df = df.copy()
copy_df = copy_df.drop('store1')
copy_df
# Out:
#         Cost Item Purchased   Name
# store2   5.0      Bird Seed  Vinod

# %%
df
# Out:
#         Cost Item Purchased   Name
# store1  22.5       Dog Food  Chris
# store1   2.5   Kitty Litter  Kevyn
# store2   5.0      Bird Seed  Vinod

# %% [markdown]
# ## del df['column_name']
#
# to delet column

# %%
del df['Cost']
df
# Out:
#        Item Purchased   Name
# store1       Dog Food  Chris
# store1   Kitty Litter  Kevyn
# store2      Bird Seed  Vinod

# %% [markdown]
# ## add new column in dataframe

# %%
df['location'] = None
df = df.drop('location')
df
# Out:
# C:\Users\SAHIL\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.
#        Item Purchased   Name location
# store1       Dog Food  Chris     None
# store1   Kitty Litter  Kevyn     None
# store2      Bird Seed  Vinod     None

# %%
df.loc['store1', ['Name', 'location']]
# Out:
#          Name location
# store1  Chris     None
# store1  Kevyn     None

# %% [markdown]
# # 5. Dataframe Indexing and Loading

# %%
df
# Out:
#         Cost Item Purchased   Name
# store1  22.5       Dog Food  Chris
# store1   2.5   Kitty Litter  Kevyn
# store2   5.0      Bird Seed  Vinod

# %%
costs = df['Cost']
costs
# Out:
# store1    22.5
# store1     2.5
# store2     5.0
# Name: Cost, dtype: float64

# %%
costs += 2

# %%
df
# Out:
#         Cost Item Purchased   Name
# store1  24.5       Dog Food  Chris
# store1   4.5   Kitty Litter  Kevyn
# store2   7.0      Bird Seed  Vinod

# %% [markdown]
# ### use df.copy() if you dont want to update origenal one

# %% [markdown]
# ## pd.read_csv()
# ### to read csv file

# %%
df = pd.read_csv('olympics.csv')
df.head()
# Out:
#                    0         1     2     3     4      5         6     7     8  \
# 0                NaN  № Summer  01 !  02 !  03 !  Total  № Winter  01 !  02 !
# 1  Afghanistan (AFG)        13     0     0     2      2         0     0     0
# 2      Algeria (ALG)        12     5     2     8     15         3     0     0
# 3    Argentina (ARG)        23    18    24    28     70        18     0     0
# 4      Armenia (ARM)         5     1     2     9     12         6     0     0
#
#       9     10       11    12    13    14              15
# 0  03 !  Total  № Games  01 !  02 !  03 !  Combined total
# 1     0      0       13     0     0     2               2
# 2     0      0       15     5     2     8              15
# 3     0      0       41    18    24    28              70
# 4     0      0       11     1     2     9              12

# %% [markdown]
# ### if you want to skip 1st row use skiprows = 1
# ### if you want to skip index_col = 0 skipped

# %%
df = pd.read_csv('olympics.csv', index_col=0, skiprows=1)
df.head()
# Out:
#                          № Summer  01 !  02 !  03 !  Total  № Winter  01 !.1  \
# Afghanistan (AFG)              13     0     0     2      2         0       0
# Algeria (ALG)                  12     5     2     8     15         3       0
# Argentina (ARG)                23    18    24    28     70        18       0
# Armenia (ARM)                   5     1     2     9     12         6       0
# Australasia (ANZ) [ANZ]         2     3     4     5     12         0       0
#
#                          02 !.1  03 !.1  Total.1  № Games  01 !.2  02 !.2  \
# Afghanistan (AFG)             0       0        0       13       0       0
# Algeria (ALG)                 0       0        0       15       5       2
# Argentina (ARG)               0       0        0       41      18      24
# Armenia (ARM)                 0       0        0       11       1       2
# Australasia (ANZ) [ANZ]       0       0        0        2       3       4
#
#                          03 !.2  Combined total
# ...

# %% [markdown]
# ## df.columns
#
# ### returns columns name

# %%
df.columns
# Out:
# Index(['№ Summer', '01 !', '02 !', '03 !', 'Total', '№ Winter', '01 !.1',
#        '02 !.1', '03 !.1', 'Total.1', '№ Games', '01 !.2', '02 !.2', '03 !.2',
#        'Combined total'],
#       dtype='object')

# %% [markdown]
# ## df.rename(columns={old_col:'NEW_COLUMN_NAME'}, inplace=True)
#
# to manipulate the column name

# %%
for col in df.columns:
    if col[:2] == '01':
        df.rename(columns={col:'Gold' + col[4:]}, inplace=True)
    if col[:2] == '02':
        df.rename(columns={col:'Silver' + col[4:]}, inplace=True)
    if col[:2] == '03':
        df.rename(columns={col:'Bronz' + col[4:]}, inplace=True)
    if col[:1] == '№':
        df.rename(columns={col:'#' + col[2:]}, inplace=True)
        
df.head()
# Out:
#                          #Summer  Gold  Silver  Bronz  Total  #Winter  Gold.1  \
# Afghanistan (AFG)             13     0       0      2      2        0       0
# Algeria (ALG)                 12     5       2      8     15        3       0
# Argentina (ARG)               23    18      24     28     70       18       0
# Armenia (ARM)                  5     1       2      9     12        6       0
# Australasia (ANZ) [ANZ]        2     3       4      5     12        0       0
#
#                          Silver.1  Bronz.1  Total.1  #Games  Gold.2  Silver.2  \
# Afghanistan (AFG)               0        0        0      13       0         0
# Algeria (ALG)                   0        0        0      15       5         2
# Argentina (ARG)                 0        0        0      41      18        24
# Armenia (ARM)                   0        0        0      11       1         2
# Australasia (ANZ) [ANZ]         0        0        0       2       3         4
#
# ...

# %% [markdown]
# # 6. Querying a DataFrame

# %% [markdown]
# ### Use conditional operaters to get data

# %%
df['Gold']>0
# Out:
# Afghanistan (AFG)                               False
# Algeria (ALG)                                    True
# Argentina (ARG)                                  True
# Armenia (ARM)                                    True
# Australasia (ANZ) [ANZ]                          True
# Australia (AUS) [AUS] [Z]                        True
# Austria (AUT)                                    True
# Azerbaijan (AZE)                                 True
# Bahamas (BAH)                                    True
# Bahrain (BRN)                                   False
# Barbados (BAR) [BAR]                            False
# Belarus (BLR)                                    True
# Belgium (BEL)                                    True
# Bermuda (BER)                                   False
# Bohemia (BOH) [BOH] [Z]                         False
# Botswana (BOT)                                  False
# Brazil (BRA)                                     True
# ...

# %% [markdown]
# ## df.where()
#
# ### returns all column and return NaN if condition not satisfied in that row

# %%
only_gold = df.where(df['Gold']>0)
only_gold.head()
# Out:
#                          #Summer  Gold  Silver  Bronz  Total  #Winter  Gold.1  \
# Afghanistan (AFG)            NaN   NaN     NaN    NaN    NaN      NaN     NaN
# Algeria (ALG)               12.0   5.0     2.0    8.0   15.0      3.0     0.0
# Argentina (ARG)             23.0  18.0    24.0   28.0   70.0     18.0     0.0
# Armenia (ARM)                5.0   1.0     2.0    9.0   12.0      6.0     0.0
# Australasia (ANZ) [ANZ]      2.0   3.0     4.0    5.0   12.0      0.0     0.0
#
#                          Silver.1  Bronz.1  Total.1  #Games  Gold.2  Silver.2  \
# Afghanistan (AFG)             NaN      NaN      NaN     NaN     NaN       NaN
# Algeria (ALG)                 0.0      0.0      0.0    15.0     5.0       2.0
# Argentina (ARG)               0.0      0.0      0.0    41.0    18.0      24.0
# Armenia (ARM)                 0.0      0.0      0.0    11.0     1.0       2.0
# Australasia (ANZ) [ANZ]       0.0      0.0      0.0     2.0     3.0       4.0
#
# ...

# %% [markdown]
# ## only_gold['Gold'].count( )
#
# .count() returns the count of column containt

# %%
only_gold['Gold'].count()
# Out:
# 100

# %%
df['Gold'].count()
# Out:
# 147

# %% [markdown]
# ## df.dropna()
# ### .dropna() drops all NaN values

# %%
only_gold = only_gold.dropna()
only_gold.head()
# Out:
#                            #Summer   Gold  Silver  Bronz  Total  #Winter  \
# Algeria (ALG)                 12.0    5.0     2.0    8.0   15.0      3.0
# Argentina (ARG)               23.0   18.0    24.0   28.0   70.0     18.0
# Armenia (ARM)                  5.0    1.0     2.0    9.0   12.0      6.0
# Australasia (ANZ) [ANZ]        2.0    3.0     4.0    5.0   12.0      0.0
# Australia (AUS) [AUS] [Z]     25.0  139.0   152.0  177.0  468.0     18.0
#
#                            Gold.1  Silver.1  Bronz.1  Total.1  #Games  Gold.2  \
# Algeria (ALG)                 0.0       0.0      0.0      0.0    15.0     5.0
# Argentina (ARG)               0.0       0.0      0.0      0.0    41.0    18.0
# Armenia (ARM)                 0.0       0.0      0.0      0.0    11.0     1.0
# Australasia (ANZ) [ANZ]       0.0       0.0      0.0      0.0     2.0     3.0
# Australia (AUS) [AUS] [Z]     5.0       3.0      4.0     12.0    43.0   144.0
#
# ...

# %% [markdown]
# ### the shourtcut way to get all the rows from df which having gold>0

# %%
only_gold = df[df['Gold']>0]
only_gold
# Out:
#                                      #Summer  Gold  Silver  Bronz  Total  \
# Algeria (ALG)                             12     5       2      8     15
# Argentina (ARG)                           23    18      24     28     70
# Armenia (ARM)                              5     1       2      9     12
# Australasia (ANZ) [ANZ]                    2     3       4      5     12
# Australia (AUS) [AUS] [Z]                 25   139     152    177    468
# Austria (AUT)                             26    18      33     35     86
# Azerbaijan (AZE)                           5     6       5     15     26
# Bahamas (BAH)                             15     5       2      5     12
# Belarus (BLR)                              5    12      24     39     75
# Belgium (BEL)                             25    37      52     53    142
# Brazil (BRA)                              21    23      30     55    108
# Bulgaria (BUL) [H]                        19    51      85     78    214
# ...

# %% [markdown]
# ### the total rows which having Gold>0 or Gold.1>0

# %%
len(df[(df['Gold']>0)  | (df['Gold.1']>0) ])
# Out:
# 101

# %%
### get the rows which having Gold.1>0 and Gold == 0

# %%
df[(df['Gold.1']>0)  & (df['Gold']==0)]
# Out:
#                      #Summer  Gold  Silver  Bronz  Total  #Winter  Gold.1  \
# Liechtenstein (LIE)       16     0       0      0      0       18       2
#
#                      Silver.1  Bronz.1  Total.1  #Games  Gold.2  Silver.2  \
# Liechtenstein (LIE)         2        5        9      34       2         2
#
#                      Bronz.2  Combined total
# Liechtenstein (LIE)        5               9

# %%
"""
purchase_1 = pd.Series({'Name': 'Chris',
                        'Item Purchased': 'Dog Food',
                        'Cost': 22.50})
purchase_2 = pd.Series({'Name': 'Kevyn',
                        'Item Purchased': 'Kitty Litter',
                        'Cost': 2.50})
purchase_3 = pd.Series({'Name': 'Vinod',
                        'Item Purchased': 'Bird Seed',
                        'Cost': 5.00})

df = pd.DataFrame([purchase_1, purchase_2, purchase_3], index=['Store 1', 'Store 1', 'Store 2'])


# Your answer here

df = df.set_index([df.index, 'Name'])
print(df)
df.index.names = ['Location', 'Name']
print(df.index.names)
df = df.append(pd.Series(data={'Cost': 3.00, 'Item Purchased': 'Kitty Food'}, name=('Store 2', 'Kevyn')))
df


df = df.set_index([df.index, 'Name'])
df.index.names = ['Location','Name']
df = df.append(pd.Series({'Cost':2.52, 'Item Purchased':'Puri'}, name=('Store 2','sahil')))
df
"""
# Out:
# "\npurchase_1 = pd.Series({'Name': 'Chris',\n                        'Item Purchased': 'Dog Food',\n                        'Cost': 22.50})\npurchase_2 = pd.Series({'Name': 'Kevyn',\n                        'Item Purchased': 'Kitty Litter',\n                        'Cost': 2.50})\npurchase_3 = pd.Series({'Name': 'Vinod',\n                        'Item Purchased': 'Bird Seed',\n                        'Cost': 5.00})\n\ndf = pd.DataFrame([purchase_1, purchase_2, purchase_3], index=['Store 1', 'Store 1', 'Store 2'])\n\n\n# Your answer here\n\ndf = df.set_index([df.index, 'Name'])\nprint(df)\ndf.index.names = ['Location', 'Name']\nprint(df.index.names)\ndf = df.append(pd.Series(data={'Cost': 3.00, 'Item Purchased': 'Kitty Food'}, name=('Store 2', 'Kevyn')))\ndf\n\n\ndf = df.set_index([df.index, 'Name'])\ndf.index.names = ['Location','Name']\ndf = df.append(pd.Series({'Cost':2.52, 'Item Purchased':'Puri'}, name=('Store 2','sahil')))\ndf\n"

# %% [markdown]
# # 7. Indexing Dataframes

# %%
df.head()
# Out:
#                          #Summer  Gold  Silver  Bronz  Total  #Winter  Gold.1  \
# Afghanistan (AFG)             13     0       0      2      2        0       0
# Algeria (ALG)                 12     5       2      8     15        3       0
# Argentina (ARG)               23    18      24     28     70       18       0
# Armenia (ARM)                  5     1       2      9     12        6       0
# Australasia (ANZ) [ANZ]        2     3       4      5     12        0       0
#
#                          Silver.1  Bronz.1  Total.1  #Games  Gold.2  Silver.2  \
# Afghanistan (AFG)               0        0        0      13       0         0
# Algeria (ALG)                   0        0        0      15       5         2
# Argentina (ARG)                 0        0        0      41      18        24
# Armenia (ARM)                   0        0        0      11       1         2
# Australasia (ANZ) [ANZ]         0        0        0       2       3         4
#
# ...

# %% [markdown]
# ## df.index
#
# ### df.index returns all index

# %%
df.index
# Out:
# Index(['#Summer', 'Gold', 'Silver', 'Bronz', 'Total', '#Winter', 'Gold.1',
#        'Silver.1', 'Bronz.1', 'Total.1', '#Games', 'Gold.2', 'Silver.2',
#        'Bronz.2', 'Combined total'],
#       dtype='object')

# %% [markdown]
# ### add new column to dataframe and set it as all indexes

# %%
df['country'] = df.index
df.head()
# Out:
#                          #Summer  Gold  Silver  Bronz  Total  #Winter  Gold.1  \
# Afghanistan (AFG)             13     0       0      2      2        0       0
# Algeria (ALG)                 12     5       2      8     15        3       0
# Argentina (ARG)               23    18      24     28     70       18       0
# Armenia (ARM)                  5     1       2      9     12        6       0
# Australasia (ANZ) [ANZ]        2     3       4      5     12        0       0
#
#                          Silver.1  Bronz.1  Total.1  #Games  Gold.2  Silver.2  \
# Afghanistan (AFG)               0        0        0      13       0         0
# Algeria (ALG)                   0        0        0      15       5         2
# Argentina (ARG)                 0        0        0      41      18        24
# Armenia (ARM)                   0        0        0      11       1         2
# Australasia (ANZ) [ANZ]         0        0        0       2       3         4
#
# ...

# %% [markdown]
# ## df.set_index()
#
# ### set the any column as index

# %%
df = df.set_index('Gold')
df.head()
# Out:
#       #Summer  Silver  Bronz  Total  #Winter  Gold.1  Silver.1  Bronz.1  \
# Gold
# 0          13       0      2      2        0       0         0        0
# 5          12       2      8     15        3       0         0        0
# 18         23      24     28     70       18       0         0        0
# 1           5       2      9     12        6       0         0        0
# 3           2       4      5     12        0       0         0        0
#
#       Total.1  #Games  Gold.2  Silver.2  Bronz.2  Combined total  \
# Gold
# 0           0      13       0         0        2               2
# 5           0      15       5         2        8              15
# 18          0      41      18        24       28              70
# 1           0      11       1         2        9              12
# 3           0       2       3         4        5              12
#
#                       country
# Gold
# 0           Afghanistan (AFG)
# 5               Algeria (ALG)
# ...

# %% [markdown]
# ## df.reset_index()
# ### reset it to the defoult index number

# %%
df = df.reset_index()
df.head()
# Out:
#    Gold  #Summer  Silver  Bronz  Total  #Winter  Gold.1  Silver.1  Bronz.1  \
# 0     0       13       0      2      2        0       0         0        0
# 1     5       12       2      8     15        3       0         0        0
# 2    18       23      24     28     70       18       0         0        0
# 3     1        5       2      9     12        6       0         0        0
# 4     3        2       4      5     12        0       0         0        0
#
#    Total.1  #Games  Gold.2  Silver.2  Bronz.2  Combined total  \
# 0        0      13       0         0        2               2
# 1        0      15       5         2        8              15
# 2        0      41      18        24       28              70
# 3        0      11       1         2        9              12
# 4        0       2       3         4        5              12
#
#                    country
# 0        Afghanistan (AFG)
# 1            Algeria (ALG)
# 2          Argentina (ARG)
# ...

# %% [markdown]
# ### read the census.csv

# %%
df = pd.read_csv('census.csv')
df.head()
# Out:
#    SUMLEV  REGION  DIVISION  STATE  COUNTY   STNAME         CTYNAME  \
# 0      40       3         6      1       0  Alabama         Alabama
# 1      50       3         6      1       1  Alabama  Autauga County
# 2      50       3         6      1       3  Alabama  Baldwin County
# 3      50       3         6      1       5  Alabama  Barbour County
# 4      50       3         6      1       7  Alabama     Bibb County
#
#    CENSUS2010POP  ESTIMATESBASE2010  POPESTIMATE2010     ...       \
# 0        4779736            4780127          4785161     ...
# 1          54571              54571            54660     ...
# 2         182265             182265           183193     ...
# 3          27457              27457            27341     ...
# 4          22915              22919            22861     ...
#
#    RDOMESTICMIG2011  RDOMESTICMIG2012  RDOMESTICMIG2013  RDOMESTICMIG2014  \
# 0          0.002295         -0.193196          0.381066          0.582002
# ...

# %% [markdown]
# ## .unique()
#
# ### get the unique values from column

# %%
df['SUMLEV'].unique()
# Out:
# array([40, 50], dtype=int64)

# %% [markdown]
# ### Get the all the rows whose SUMLEV is 50

# %%
df = df[df['SUMLEV'] == 50]
df.head()
# Out:
#    SUMLEV  REGION  DIVISION  STATE  COUNTY   STNAME         CTYNAME  \
# 1      50       3         6      1       1  Alabama  Autauga County
# 2      50       3         6      1       3  Alabama  Baldwin County
# 3      50       3         6      1       5  Alabama  Barbour County
# 4      50       3         6      1       7  Alabama     Bibb County
# 5      50       3         6      1       9  Alabama   Blount County
#
#    CENSUS2010POP  ESTIMATESBASE2010  POPESTIMATE2010     ...       \
# 1          54571              54571            54660     ...
# 2         182265             182265           183193     ...
# 3          27457              27457            27341     ...
# 4          22915              22919            22861     ...
# 5          57322              57322            57373     ...
#
#    RDOMESTICMIG2011  RDOMESTICMIG2012  RDOMESTICMIG2013  RDOMESTICMIG2014  \
# 1          7.242091         -2.915927         -3.012349          2.265971
# ...

# %% [markdown]
# ### only keep the mentioned columns

# %%
columns_to_keep = ['STNAME',
                   'CTYNAME',
                   'BIRTHS2010',
                   'BIRTHS2011',
                   'BIRTHS2012',
                   'BIRTHS2013',
                   'BIRTHS2014',
                   'BIRTHS2015',
                   'POPESTIMATE2010',
                   'POPESTIMATE2011',
                   'POPESTIMATE2012',
                   'POPESTIMATE2013',
                   'POPESTIMATE2014',
                   'POPESTIMATE2015']

df = df[columns_to_keep]
df.head()
# Out:
#     STNAME         CTYNAME  BIRTHS2010  BIRTHS2011  BIRTHS2012  BIRTHS2013  \
# 1  Alabama  Autauga County         151         636         615         574
# 2  Alabama  Baldwin County         517        2187        2092        2160
# 3  Alabama  Barbour County          70         335         300         283
# 4  Alabama     Bibb County          44         266         245         259
# 5  Alabama   Blount County         183         744         710         646
#
#    BIRTHS2014  BIRTHS2015  POPESTIMATE2010  POPESTIMATE2011  POPESTIMATE2012  \
# 1         623         600            54660            55253            55175
# 2        2186        2240           183193           186659           190396
# 3         260         269            27341            27226            27159
# 4         247         253            22861            22733            22642
# 5         618         603            57373            57711            57776
#
# ...

# %% [markdown]
# ## df.set_index([column_names])
# ### .set_index it set index to given columns
#
# #### make STNAME CTYNAME  as index

# %%
df = df.set_index(['STNAME', 'CTYNAME'])
df.head()
# Out:
#                         BIRTHS2010  BIRTHS2011  BIRTHS2012  BIRTHS2013  \
# STNAME  CTYNAME
# Alabama Autauga County         151         636         615         574
#         Baldwin County         517        2187        2092        2160
#         Barbour County          70         335         300         283
#         Bibb County             44         266         245         259
#         Blount County          183         744         710         646
#
#                         BIRTHS2014  BIRTHS2015  POPESTIMATE2010  \
# STNAME  CTYNAME
# Alabama Autauga County         623         600            54660
#         Baldwin County        2186        2240           183193
#         Barbour County         260         269            27341
#         Bibb County            247         253            22861
#         Blount County          618         603            57373
#
#                         POPESTIMATE2011  POPESTIMATE2012  POPESTIMATE2013  \
# STNAME  CTYNAME
# ...

# %%
df.loc['Michigan', 'Washtenaw County']
# Out:
# BIRTHS2010            977
# BIRTHS2011           3826
# BIRTHS2012           3780
# BIRTHS2013           3662
# BIRTHS2014           3683
# BIRTHS2015           3709
# POPESTIMATE2010    345563
# POPESTIMATE2011    349048
# POPESTIMATE2012    351213
# POPESTIMATE2013    354289
# POPESTIMATE2014    357029
# POPESTIMATE2015    358880
# Name: (Michigan, Washtenaw County), dtype: int64

# %%
df.loc[[('Michigan', 'Washtenaw County'),('Michigan', 'Washtenaw County')]]
# Out:
#                            BIRTHS2010  BIRTHS2011  BIRTHS2012  BIRTHS2013  \
# STNAME   CTYNAME
# Michigan Washtenaw County         977        3826        3780        3662
#          Washtenaw County         977        3826        3780        3662
#
#                            BIRTHS2014  BIRTHS2015  POPESTIMATE2010  \
# STNAME   CTYNAME
# Michigan Washtenaw County        3683        3709           345563
#          Washtenaw County        3683        3709           345563
#
#                            POPESTIMATE2011  POPESTIMATE2012  POPESTIMATE2013  \
# STNAME   CTYNAME
# Michigan Washtenaw County           349048           351213           354289
#          Washtenaw County           349048           351213           354289
#
#                            POPESTIMATE2014  POPESTIMATE2015
# STNAME   CTYNAME
# Michigan Washtenaw County           357029           358880
#          Washtenaw County           357029           358880

# %% [markdown]
# # 9. Missing values¶

# %%
df = pd.read_csv('log.csv')
df
# Out:
#           time    user          video  playback position paused  volume
# 0   1469974424  cheryl     intro.html                  5  False    10.0
# 1   1469974454  cheryl     intro.html                  6    NaN     NaN
# 2   1469974544  cheryl     intro.html                  9    NaN     NaN
# 3   1469974574  cheryl     intro.html                 10    NaN     NaN
# 4   1469977514     bob     intro.html                  1    NaN     NaN
# 5   1469977544     bob     intro.html                  1    NaN     NaN
# 6   1469977574     bob     intro.html                  1    NaN     NaN
# 7   1469977604     bob     intro.html                  1    NaN     NaN
# 8   1469974604  cheryl     intro.html                 11    NaN     NaN
# 9   1469974694  cheryl     intro.html                 14    NaN     NaN
# 10  1469974724  cheryl     intro.html                 15    NaN     NaN
# 11  1469974454     sue  advanced.html                 24    NaN     NaN
# ...

# %%
df.fillna?

# %% [markdown]
# ## df.fillna()
#
# ### .fillna()
# used to fill NaN values

# %% [markdown]
# ### set time as an index
# ## .set_index('time')

# %%
df = df.set_index('time')
df
# Out:
#             index    user          video  playback position paused  volume
# time
# 1469974424      0  cheryl     intro.html                  5  False    10.0
# 1469974424      1     sue  advanced.html                 23  False    10.0
# 1469974454      2  cheryl     intro.html                  6    NaN     NaN
# 1469974454      3     sue  advanced.html                 24    NaN     NaN
# 1469974484      4  cheryl     intro.html                  7    NaN     NaN
# 1469974514      5  cheryl     intro.html                  8    NaN     NaN
# 1469974524      6     sue  advanced.html                 25    NaN     NaN
# 1469974544      7  cheryl     intro.html                  9    NaN     NaN
# 1469974554      8     sue  advanced.html                 26    NaN     NaN
# 1469974574      9  cheryl     intro.html                 10    NaN     NaN
# 1469974604     10  cheryl     intro.html                 11    NaN     NaN
# ...

# %% [markdown]
# ## df.sort_index()
#
# ### .sort_index() sort the index

# %%
df = df.sort_index()
df
# Out:
#             index    user          video  playback position paused  volume
# time
# 1469974424      0  cheryl     intro.html                  5  False    10.0
# 1469974424      1     sue  advanced.html                 23  False    10.0
# 1469974454      2  cheryl     intro.html                  6    NaN     NaN
# 1469974454      3     sue  advanced.html                 24    NaN     NaN
# 1469974484      4  cheryl     intro.html                  7    NaN     NaN
# 1469974514      5  cheryl     intro.html                  8    NaN     NaN
# 1469974524      6     sue  advanced.html                 25    NaN     NaN
# 1469974544      7  cheryl     intro.html                  9    NaN     NaN
# 1469974554      8     sue  advanced.html                 26    NaN     NaN
# 1469974574      9  cheryl     intro.html                 10    NaN     NaN
# 1469974604     10  cheryl     intro.html                 11    NaN     NaN
# ...

# %% [markdown]
# ## df.reset_index()
#
# ### reset index to 0 to all index

# %%
df = df.reset_index()
df
# Out:
#           time  index    user          video  playback position paused  volume
# 0   1469974424      0  cheryl     intro.html                  5  False    10.0
# 1   1469974424      1     sue  advanced.html                 23  False    10.0
# 2   1469974454      2  cheryl     intro.html                  6    NaN     NaN
# 3   1469974454      3     sue  advanced.html                 24    NaN     NaN
# 4   1469974484      4  cheryl     intro.html                  7    NaN     NaN
# 5   1469974514      5  cheryl     intro.html                  8    NaN     NaN
# 6   1469974524      6     sue  advanced.html                 25    NaN     NaN
# 7   1469974544      7  cheryl     intro.html                  9    NaN     NaN
# 8   1469974554      8     sue  advanced.html                 26    NaN     NaN
# 9   1469974574      9  cheryl     intro.html                 10    NaN     NaN
# 10  1469974604     10  cheryl     intro.html                 11    NaN     NaN
# ...

# %% [markdown]
# ## make index as time and user
# ### .set_index()

# %%
df = df.set_index(['time','user'])
df
# Out:
#                    index          video  playback position paused  volume
# time       user
# 1469974424 cheryl      0     intro.html                  5  False    10.0
#            sue         1  advanced.html                 23  False    10.0
# 1469974454 cheryl      2     intro.html                  6    NaN     NaN
#            sue         3  advanced.html                 24    NaN     NaN
# 1469974484 cheryl      4     intro.html                  7    NaN     NaN
# 1469974514 cheryl      5     intro.html                  8    NaN     NaN
# 1469974524 sue         6  advanced.html                 25    NaN     NaN
# 1469974544 cheryl      7     intro.html                  9    NaN     NaN
# 1469974554 sue         8  advanced.html                 26    NaN     NaN
# 1469974574 cheryl      9     intro.html                 10    NaN     NaN
# 1469974604 cheryl     10     intro.html                 11    NaN     NaN
# ...

# %% [markdown]
# ## df.filna(method='ffill')
#
# ### ffill to fill previous value to NaN

# %%
df = df.fillna(method = 'ffill')
df.head()
# Out:
#                    index          video  playback position  paused  volume
# time       user
# 1469974424 cheryl      0     intro.html                  5   False    10.0
#            sue         1  advanced.html                 23   False    10.0
# 1469974454 cheryl      2     intro.html                  6   False    10.0
#            sue         3  advanced.html                 24   False    10.0
# 1469974484 cheryl      4     intro.html                  7   False    10.0
